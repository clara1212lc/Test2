# %%
somelist =  [1,12,-2,53,23,9,17] 

def my_min_function(somelist):
    min_value = None
    for value in somelist:
        if not min_value:
            min_value = value
        elif value < min_value:
            min_value = value
    print (min_value)

my_min_function(somelist)
# Out:
# -2
